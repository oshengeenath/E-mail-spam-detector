# %%
# import necerssary libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataSet = pd.read_csv('spamData.csv')
dataSet
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4205            0.31               0.00           0.62           0.0
# 4206            0.00               0.00           0.00           0.0
# 4207            0.30               0.00           0.30           0.0
# 4208            0.96               0.00           0.00           0.0
# 4209            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4205           0.00            0.31              0.00                0.00
# 4206           0.00            0.00              0.00                0.00
# 4207           0.00            0.00              0.00                0.00
# 4208           0.32            0.00              0.00                0.00
# 4209           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0                0.00            0.00  ...        0.000        0.000
# 1                0.00            0.94  ...        0.000        0.132
# 2                0.64            0.25  ...        0.010        0.143
# 3                0.31            0.63  ...        0.000        0.137
# 4                0.31            0.63  ...        0.000        0.135
# ...               ...             ...  ...          ...          ...
# 4205             0.00            0.00  ...        0.000        0.232
# 4206             0.00            0.00  ...        0.000        0.000
# 4207             0.00            0.00  ...        0.102        0.718
# 4208             0.00            0.00  ...        0.000        0.057
# 4209             0.00            0.00  ...        0.000        0.000
#
#       char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0             0.0        0.778        0.000        0.000
# 1             0.0        0.372        0.180        0.048
# 2             0.0        0.276        0.184        0.010
# 3             0.0        0.137        0.000        0.000
# 4             0.0        0.135        0.000        0.000
# ...           ...          ...          ...          ...
# 4205          0.0        0.000        0.000        0.000
# 4206          0.0        0.353        0.000        0.000
# 4207          0.0        0.000        0.000        0.000
# 4208          0.0        0.000        0.000        0.000
# 4209          0.0        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4205                       1.142                           3
# 4206                       1.555                           4
# 4207                       1.404                           6
# 4208                       1.147                           5
# 4209                       1.250                           5
#
#       capital_run_length_total  spam
# 0                          278     1
# 1                         1028     1
# 2                         2259     1
# 3                          191     1
# 4                          191     1
# ...                        ...   ...
# 4205                        88     0
# 4206                        14     0
# 4207                       118     0
# 4208                        78     0
# 4209                        40     0
#
# [4210 rows x 58 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(dataSet)

# %%
new_data=pd.DataFrame(data=scaled_data, columns= dataSet.columns)

# %%
new_data.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count    4.210000e+03       4.210000e+03   4.210000e+03   4210.000000
# mean     4.725700e-17       1.350200e-17   2.700400e-17      0.000000
# std      1.000119e+00       1.000119e+00   1.000119e+00      1.000119
# min     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 25%     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 50%     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 75%     -3.479216e-01      -2.480275e-01   2.880349e-01     -0.046644
# max      1.478696e+01       3.119145e+01   9.325045e+00     31.609920
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count   4.210000e+03    4.210000e+03       4210.000000        4.210000e+03
# mean    4.050600e-17   -1.350200e-17          0.000000       -1.350200e-17
# std     1.000119e+00    1.000119e+00          1.000119        1.000119e+00
# min    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 25%    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 50%    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 75%     1.231299e-01   -3.502046e-01         -0.295731       -2.632646e-01
# max     1.406769e+01    2.095434e+01         18.005710        2.681886e+01
#
#        word_freq_order  word_freq_mail  ...  char_freq_;   char_freq_(  \
# count      4210.000000    4.210000e+03  ...  4210.000000  4.210000e+03
# mean          0.000000   -8.776300e-17  ...     0.000000 -6.751000e-18
# std           1.000119    1.000119e+00  ...     1.000119  1.000119e+00
# min          -0.325617   -3.783664e-01  ...    -0.160010 -5.252942e-01
# 25%          -0.325617   -3.783664e-01  ...    -0.160010 -5.252942e-01
# 50%          -0.325617   -3.783664e-01  ...    -0.160010 -2.590883e-01
# 75%          -0.325617   -8.897950e-02  ...    -0.160010  1.821569e-01
# max          18.319574    2.731139e+01  ...    17.206130  3.503689e+01
#
#         char_freq_[   char_freq_!   char_freq_$   char_freq_#  \
# count  4.210000e+03  4.210000e+03  4.210000e+03  4.210000e+03
# mean   1.350200e-17 -2.700400e-17 -2.700400e-17  2.700400e-17
# std    1.000119e+00  1.000119e+00  1.000119e+00  1.000119e+00
# min   -1.643641e-01 -3.334068e-01 -3.173253e-01 -1.050711e-01
# 25%   -1.643641e-01 -3.334068e-01 -3.173253e-01 -1.050711e-01
# 50%   -1.643641e-01 -3.144319e-01 -3.173253e-01 -1.050711e-01
# 75%   -1.643641e-01  5.913558e-02 -9.619715e-02 -1.050711e-01
# max    3.843832e+01  3.818318e+01  2.472857e+01  4.538756e+01
#
#        capital_run_length_average  capital_run_length_longest  \
# count                4.210000e+03                4.210000e+03
# mean                -1.350200e-17               -1.350200e-17
# std                  1.000119e+00                1.000119e+00
# min                 -1.322705e-01               -2.562653e-01
# 25%                 -1.133376e-01               -2.261989e-01
# 50%                 -9.313751e-02               -1.861104e-01
# 75%                 -5.060267e-02               -4.078958e-02
# max                  3.310208e+01                4.979423e+01
#
#        capital_run_length_total         spam
# count              4.210000e+03  4210.000000
# mean              -2.700400e-17     0.000000
# std                1.000119e+00     1.000119
# min               -4.691088e-01    -0.814478
# 25%               -4.060613e-01    -0.814478
# 50%               -3.066403e-01    -0.814478
# 75%               -2.818053e-02     1.227780
# max                2.513787e+01     1.227780
#
# [8 rows x 58 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA()
principalComponents = pca.fit_transform(new_data)

# %%
pca = PCA(n_components=44)
new_data = pca.fit_transform(new_data)

# This will be the new data fed to the algorithm.
new_data = pd.DataFrame(data = new_data
             , columns = ['PC1', 'PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20',
                         'PC21', 'PC22','PC23','PC24','PC25','PC26','PC27','PC28','PC29','PC30','PC31','PC32','PC33','PC34','PC35','PC36','PC37','PC38','PC39','PC40',
                         'PC41','PC42','PC43','PC44'])

# %%
new_data.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.959822  0.409799 -0.704929  0.051580 -0.290668 -0.306134 -0.093086
# 1 -1.577182  2.120013  0.145479 -0.496047  0.054572 -1.145341 -0.554305
# 2 -2.027952  4.587549  3.385858 -1.134536  1.772967 -1.325542 -3.197417
# 3 -1.069772  0.743204 -0.596521 -0.016802 -0.169433  0.720528  0.345534
# 4 -1.070585  0.742546 -0.598661 -0.017069 -0.169453  0.721089  0.343808
#
#         PC8       PC9      PC10  ...      PC35      PC36      PC37      PC38  \
# 0  0.361945  1.748484  0.047490  ...  0.350958  0.493521 -0.003224  0.124146
# 1  0.248781 -0.301236  0.687752  ... -0.255786 -0.193349 -0.370184 -0.149000
# 2 -1.351290  1.000900 -2.300463  ...  2.071324 -0.497171 -0.475821 -0.226461
# 3 -0.442470 -0.371834 -0.238872  ...  0.332525  0.237236  0.047659  0.291773
# 4 -0.443796 -0.372161 -0.238068  ...  0.331831  0.238512  0.048793  0.292206
#
#        PC39      PC40      PC41      PC42      PC43      PC44
# 0  0.198488  0.195142  0.259325  0.229454 -0.322279  0.415170
# 1  0.014758  0.241073  0.329489  0.573903  0.095360  0.348091
# 2 -0.434991  0.937981  0.748530  0.390069  0.124815 -0.949639
# 3 -0.402590  0.539938  0.718841 -0.696897  0.298188 -0.306967
# 4 -0.402535  0.540261  0.718030 -0.695561  0.298101 -0.306022
#
# [5 rows x 44 columns]

# %%
print(pca.explained_variance_)
# Out:
# [6.34931299 3.59100245 2.02185183 1.62967851 1.55865675 1.47438359
#  1.41600731 1.36784098 1.29487467 1.25871558 1.2407874  1.16188979
#  1.14582263 1.10619576 1.09853385 1.06509372 1.0538857  1.02941765
#  1.01693566 1.00182016 0.98029575 0.96919631 0.95331083 0.94502238
#  0.93891097 0.91879885 0.90728988 0.89578195 0.8739091  0.86558633
#  0.83275388 0.82196138 0.8102407  0.8045042  0.78869363 0.76103413
#  0.75973285 0.74232418 0.72792032 0.70614368 0.68247205 0.67169376
#  0.6388771  0.63152684]

# %%
print(pca.components_)
# Out:
# [[-0.05217651 -0.0253257  -0.05860725 ... -0.04370118 -0.05888214
#   -0.16243749]
#  [ 0.11983795  0.09668073  0.12556814 ...  0.20153729  0.17812633
#    0.3540039 ]
#  [-0.01556247 -0.01189854 -0.01805272 ...  0.47902828  0.40099379
#   -0.06406225]
#  ...
#  [-0.14040874  0.18017468  0.00474114 ...  0.04415368  0.48082289
#    0.03594148]
#  [ 0.14626655  0.07894758  0.07058464 ...  0.02322847  0.13271103
#    0.04108523]
#  [ 0.12617806 -0.30895596  0.00651519 ... -0.01978394  0.29536132
#    0.12332822]]

# %% [markdown]
# Scree plot

# %%
plt.plot((np.arange(pca.n_components_)),pca.explained_variance_ratio_,"bo-",linewidth=2)
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# Variance Explanation plot

# %%
plt.bar(range(1,len(pca.explained_variance_ratio_)+1),pca.explained_variance_ratio_,alpha=0.5,align="center")
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.title('Variance Explanation Plot')
plt.show()

# %% [markdown]
# Cumulative variance plot

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %% [markdown]
# Decision Tree

# %%
x = new_data
x
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.959822  0.409799 -0.704929  0.051580 -0.290668 -0.306134 -0.093086
# 1    -1.577182  2.120013  0.145479 -0.496047  0.054572 -1.145341 -0.554305
# 2    -2.027952  4.587549  3.385858 -1.134536  1.772967 -1.325542 -3.197417
# 3    -1.069772  0.743204 -0.596521 -0.016802 -0.169433  0.720528  0.345534
# 4    -1.070585  0.742546 -0.598661 -0.017069 -0.169453  0.721089  0.343808
# ...        ...       ...       ...       ...       ...       ...       ...
# 4205 -0.247325 -1.196334 -0.071708  0.545931  0.392174 -0.820651  0.140471
# 4206 -0.630632 -0.960303 -1.097031 -0.492040 -0.860255 -0.707315  0.887194
# 4207 -0.095736 -0.906372  0.406632  0.144166  0.172270 -1.020985  0.267443
# 4208 -0.399716 -1.063008 -0.433150  0.276444 -0.093557 -0.857546  0.434120
# 4209 -0.558281 -1.056123 -0.876731 -0.480220 -0.550984 -1.434113  0.517961
#
#            PC8       PC9      PC10  ...      PC35      PC36      PC37  \
# 0     0.361945  1.748484  0.047490  ...  0.350958  0.493521 -0.003224
# 1     0.248781 -0.301236  0.687752  ... -0.255786 -0.193349 -0.370184
# 2    -1.351290  1.000900 -2.300463  ...  2.071324 -0.497171 -0.475821
# 3    -0.442470 -0.371834 -0.238872  ...  0.332525  0.237236  0.047659
# 4    -0.443796 -0.372161 -0.238068  ...  0.331831  0.238512  0.048793
# ...        ...       ...       ...  ...       ...       ...       ...
# 4205 -0.219038 -0.068217  0.563463  ... -0.133101  0.013249  0.257972
# 4206  0.741776 -0.539647  0.188167  ... -0.043307  0.727399 -0.317007
# 4207  0.315317  0.259975  0.679654  ...  0.689531 -0.005937 -0.008357
# 4208  0.093942 -0.354675  0.882562  ...  0.497886  0.403507 -0.589610
# 4209  0.756047 -0.297150  0.037001  ... -0.162049 -0.754677 -0.040307
#
#           PC38      PC39      PC40      PC41      PC42      PC43      PC44
# 0     0.124146  0.198488  0.195142  0.259325  0.229454 -0.322279  0.415170
# 1    -0.149000  0.014758  0.241073  0.329489  0.573903  0.095360  0.348091
# 2    -0.226461 -0.434991  0.937981  0.748530  0.390069  0.124815 -0.949639
# 3     0.291773 -0.402590  0.539938  0.718841 -0.696897  0.298188 -0.306967
# 4     0.292206 -0.402535  0.540261  0.718030 -0.695561  0.298101 -0.306022
# ...        ...       ...       ...       ...       ...       ...       ...
# 4205 -0.469678 -0.114217  0.151193 -0.608733 -0.306568  0.215056 -0.113306
# 4206  0.341412  1.082899 -1.164859  0.755451  0.473375  0.327650 -0.394322
# 4207 -0.624279  0.475189 -0.593722 -0.339148 -0.880429  0.412484 -0.143948
# 4208  0.307263 -0.006423 -0.313620  0.707518 -0.422906  0.213779  0.134663
# 4209  0.000307 -0.308047 -0.431195 -0.135520  0.268268  0.493578 -0.304294
#
# [4210 rows x 44 columns]

# %%
y = dataSet["spam"]
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: spam, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (3368, 44)

# %%
x_test.shape
# Out:
# (842, 44)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=0,criterion="gini")
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# Accuracy of testing dataset

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.9465558194774347

# %% [markdown]
# Accuracy of Training dataset

# %%
predTrain = model.predict(x_train)
accuracy_score(y_train,predTrain)
# Out:
# 1.0

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model,filled=True)
plt.show()
