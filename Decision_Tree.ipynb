# %%
# import necerssary libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataSet = pd.read_csv('spamData.csv')
dataSet
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4205            0.31               0.00           0.62           0.0
# 4206            0.00               0.00           0.00           0.0
# 4207            0.30               0.00           0.30           0.0
# 4208            0.96               0.00           0.00           0.0
# 4209            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4205           0.00            0.31              0.00                0.00
# 4206           0.00            0.00              0.00                0.00
# 4207           0.00            0.00              0.00                0.00
# 4208           0.32            0.00              0.00                0.00
# 4209           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0                0.00            0.00  ...        0.000        0.000
# 1                0.00            0.94  ...        0.000        0.132
# 2                0.64            0.25  ...        0.010        0.143
# 3                0.31            0.63  ...        0.000        0.137
# 4                0.31            0.63  ...        0.000        0.135
# ...               ...             ...  ...          ...          ...
# 4205             0.00            0.00  ...        0.000        0.232
# 4206             0.00            0.00  ...        0.000        0.000
# 4207             0.00            0.00  ...        0.102        0.718
# 4208             0.00            0.00  ...        0.000        0.057
# 4209             0.00            0.00  ...        0.000        0.000
#
#       char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0             0.0        0.778        0.000        0.000
# 1             0.0        0.372        0.180        0.048
# 2             0.0        0.276        0.184        0.010
# 3             0.0        0.137        0.000        0.000
# 4             0.0        0.135        0.000        0.000
# ...           ...          ...          ...          ...
# 4205          0.0        0.000        0.000        0.000
# 4206          0.0        0.353        0.000        0.000
# 4207          0.0        0.000        0.000        0.000
# 4208          0.0        0.000        0.000        0.000
# 4209          0.0        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4205                       1.142                           3
# 4206                       1.555                           4
# 4207                       1.404                           6
# 4208                       1.147                           5
# 4209                       1.250                           5
#
#       capital_run_length_total  spam
# 0                          278     1
# 1                         1028     1
# 2                         2259     1
# 3                          191     1
# 4                          191     1
# ...                        ...   ...
# 4205                        88     0
# 4206                        14     0
# 4207                       118     0
# 4208                        78     0
# 4209                        40     0
#
# [4210 rows x 58 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(dataSet)

# %%
new_data=pd.DataFrame(data=scaled_data, columns= dataSet.columns)

# %%
new_data.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count    4.210000e+03       4.210000e+03   4.210000e+03   4210.000000
# mean     4.725700e-17       1.350200e-17   2.700400e-17      0.000000
# std      1.000119e+00       1.000119e+00   1.000119e+00      1.000119
# min     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 25%     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 50%     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 75%     -3.479216e-01      -2.480275e-01   2.880349e-01     -0.046644
# max      1.478696e+01       3.119145e+01   9.325045e+00     31.609920
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count   4.210000e+03    4.210000e+03       4210.000000        4.210000e+03
# mean    4.050600e-17   -1.350200e-17          0.000000       -1.350200e-17
# std     1.000119e+00    1.000119e+00          1.000119        1.000119e+00
# min    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 25%    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 50%    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 75%     1.231299e-01   -3.502046e-01         -0.295731       -2.632646e-01
# max     1.406769e+01    2.095434e+01         18.005710        2.681886e+01
#
#        word_freq_order  word_freq_mail  ...  char_freq_;   char_freq_(  \
# count      4210.000000    4.210000e+03  ...  4210.000000  4.210000e+03
# mean          0.000000   -8.776300e-17  ...     0.000000 -6.751000e-18
# std           1.000119    1.000119e+00  ...     1.000119  1.000119e+00
# min          -0.325617   -3.783664e-01  ...    -0.160010 -5.252942e-01
# 25%          -0.325617   -3.783664e-01  ...    -0.160010 -5.252942e-01
# 50%          -0.325617   -3.783664e-01  ...    -0.160010 -2.590883e-01
# 75%          -0.325617   -8.897950e-02  ...    -0.160010  1.821569e-01
# max          18.319574    2.731139e+01  ...    17.206130  3.503689e+01
#
#         char_freq_[   char_freq_!   char_freq_$   char_freq_#  \
# count  4.210000e+03  4.210000e+03  4.210000e+03  4.210000e+03
# mean   1.350200e-17 -2.700400e-17 -2.700400e-17  2.700400e-17
# std    1.000119e+00  1.000119e+00  1.000119e+00  1.000119e+00
# min   -1.643641e-01 -3.334068e-01 -3.173253e-01 -1.050711e-01
# 25%   -1.643641e-01 -3.334068e-01 -3.173253e-01 -1.050711e-01
# 50%   -1.643641e-01 -3.144319e-01 -3.173253e-01 -1.050711e-01
# 75%   -1.643641e-01  5.913558e-02 -9.619715e-02 -1.050711e-01
# max    3.843832e+01  3.818318e+01  2.472857e+01  4.538756e+01
#
#        capital_run_length_average  capital_run_length_longest  \
# count                4.210000e+03                4.210000e+03
# mean                -1.350200e-17               -1.350200e-17
# std                  1.000119e+00                1.000119e+00
# min                 -1.322705e-01               -2.562653e-01
# 25%                 -1.133376e-01               -2.261989e-01
# 50%                 -9.313751e-02               -1.861104e-01
# 75%                 -5.060267e-02               -4.078958e-02
# max                  3.310208e+01                4.979423e+01
#
#        capital_run_length_total         spam
# count              4.210000e+03  4210.000000
# mean              -2.700400e-17     0.000000
# std                1.000119e+00     1.000119
# min               -4.691088e-01    -0.814478
# 25%               -4.060613e-01    -0.814478
# 50%               -3.066403e-01    -0.814478
# 75%               -2.818053e-02     1.227780
# max                2.513787e+01     1.227780
#
# [8 rows x 58 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA()
principalComponents = pca.fit_transform(new_data)

# %%
plt.scatter(principalComponents[:, 0], principalComponents[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
pca = PCA(n_components=44)
new_data = pca.fit_transform(new_data)

# This will be the new data fed to the algorithm.
new_data = pd.DataFrame(data = new_data
             , columns = ['PC1', 'PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20',
                         'PC21', 'PC22','PC23','PC24','PC25','PC26','PC27','PC28','PC29','PC30','PC31','PC32','PC33','PC34','PC35','PC36','PC37','PC38','PC39','PC40',
                         'PC41','PC42','PC43','PC44'])

# %%
new_data.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.959822  0.409832 -0.704821  0.052518 -0.290825 -0.308893 -0.093813
# 1 -1.577182  2.120018  0.145537 -0.496364  0.054543 -1.145735 -0.555003
# 2 -2.027951  4.587554  3.385769 -1.134577  1.772433 -1.325566 -3.196452
# 3 -1.069772  0.743223 -0.596410 -0.016728 -0.169443  0.719155  0.344535
# 4 -1.070585  0.742565 -0.598551 -0.016986 -0.169464  0.719705  0.342813
#
#         PC8       PC9      PC10  ...      PC35      PC36      PC37      PC38  \
# 0  0.363433  1.750658  0.042299  ...  0.379841  0.463963 -0.033593  0.121712
# 1  0.249497 -0.301596  0.685864  ... -0.240603 -0.239443 -0.340447 -0.152396
# 2 -1.350596  1.001469 -2.299366  ...  2.067250 -0.552997 -0.414697 -0.244368
# 3 -0.441487 -0.371384 -0.242707  ...  0.356034  0.220501  0.040036  0.288662
# 4 -0.442811 -0.371695 -0.241911  ...  0.355373  0.221822  0.041109  0.289109
#
#        PC39      PC40      PC41      PC42      PC43      PC44
# 0  0.191670  0.169605  0.284248  0.230342 -0.332480  0.370024
# 1  0.011070  0.232483  0.359900  0.551120  0.075459  0.352546
# 2 -0.432959  0.940606  0.775847  0.361809  0.138307 -0.934078
# 3 -0.409935  0.513992  0.717740 -0.725420  0.312924 -0.312186
# 4 -0.409893  0.514245  0.716932 -0.723873  0.312845 -0.311436
#
# [5 rows x 44 columns]

# %%
print(pca.explained_variance_)
# Out:
# [6.34931299 3.59100245 2.02185185 1.62967693 1.55865661 1.47438156
#  1.41600521 1.36783997 1.29486894 1.25871991 1.24078558 1.16189052
#  1.1458293  1.10620487 1.09852079 1.06508166 1.05386171 1.02942329
#  1.01692162 1.00181858 0.98028059 0.9691876  0.95331072 0.94496733
#  0.93888053 0.91878058 0.907338   0.89586213 0.87378498 0.86557962
#  0.83266084 0.82202173 0.81020177 0.80462749 0.78826    0.7609421
#  0.75950745 0.7422947  0.72787587 0.70556197 0.68234898 0.67169895
#  0.63895288 0.63197362]

# %%
print(pca.components_)
# Out:
# [[-0.05217651 -0.0253257  -0.05860725 ... -0.04370118 -0.05888213
#   -0.1624375 ]
#  [ 0.11983792  0.0966808   0.12556825 ...  0.20153891  0.17812558
#    0.35400592]
#  [-0.01556056 -0.01189684 -0.0180532  ...  0.47902113  0.40099188
#   -0.06404184]
#  ...
#  [-0.1454484   0.17538476  0.00632449 ...  0.0545741   0.47419151
#    0.0330853 ]
#  [ 0.14324474  0.08702355  0.07019217 ...  0.02900643  0.11769436
#    0.03818471]
#  [ 0.12977053 -0.30216045  0.01083272 ... -0.0316462   0.30736225
#    0.11394537]]

# %% [markdown]
# Scree plot

# %%
plt.plot((np.arange(pca.n_components_)),pca.explained_variance_ratio_,"bo-",linewidth=2)
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# Variance Explanation plot

# %%
plt.bar(range(1,len(pca.explained_variance_ratio_)+1),pca.explained_variance_ratio_,alpha=0.5,align="center")
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.title('Variance Explanation Plot')
plt.show()

# %% [markdown]
# Cumulative variance plot

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %% [markdown]
# Decision Tree

# %%
x = new_data
x
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.959822  0.409832 -0.704821  0.052518 -0.290825 -0.308893 -0.093813
# 1    -1.577182  2.120018  0.145537 -0.496364  0.054543 -1.145735 -0.555003
# 2    -2.027951  4.587554  3.385769 -1.134577  1.772433 -1.325566 -3.196452
# 3    -1.069772  0.743223 -0.596410 -0.016728 -0.169443  0.719155  0.344535
# 4    -1.070585  0.742565 -0.598551 -0.016986 -0.169464  0.719705  0.342813
# ...        ...       ...       ...       ...       ...       ...       ...
# 4205 -0.247325 -1.196343 -0.071704  0.545640  0.392168 -0.820199  0.140712
# 4206 -0.630632 -0.960314 -1.097123 -0.492168 -0.860295 -0.706170  0.888052
# 4207 -0.095736 -0.906403  0.406677  0.141880  0.172415 -1.018102  0.266637
# 4208 -0.399716 -1.063012 -0.433189  0.276678 -0.093563 -0.857386  0.434705
# 4209 -0.558281 -1.056126 -0.876773 -0.480285 -0.551017 -1.433584  0.518383
#
#            PC8       PC9      PC10  ...      PC35      PC36      PC37  \
# 0     0.363433  1.750658  0.042299  ...  0.379841  0.463963 -0.033593
# 1     0.249497 -0.301596  0.685864  ... -0.240603 -0.239443 -0.340447
# 2    -1.350596  1.001469 -2.299366  ...  2.067250 -0.552997 -0.414697
# 3    -0.441487 -0.371384 -0.242707  ...  0.356034  0.220501  0.040036
# 4    -0.442811 -0.371695 -0.241911  ...  0.355373  0.221822  0.041109
# ...        ...       ...       ...  ...       ...       ...       ...
# 4205 -0.219256 -0.068402  0.564153  ... -0.132858  0.048194  0.251181
# 4206  0.741018 -0.540045  0.191174  ... -0.063563  0.704823 -0.412336
# 4207  0.314879  0.256210  0.681898  ...  0.681189  0.015599 -0.031602
# 4208  0.093551 -0.354230  0.883719  ...  0.508719  0.333979 -0.621845
# 4209  0.755660 -0.297393  0.038377  ... -0.170712 -0.744598  0.029249
#
#           PC38      PC39      PC40      PC41      PC42      PC43      PC44
# 0     0.121712  0.191670  0.169605  0.284248  0.230342 -0.332480  0.370024
# 1    -0.152396  0.011070  0.232483  0.359900  0.551120  0.075459  0.352546
# 2    -0.244368 -0.432959  0.940606  0.775847  0.361809  0.138307 -0.934078
# 3     0.288662 -0.409935  0.513992  0.717740 -0.725420  0.312924 -0.312186
# 4     0.289109 -0.409893  0.514245  0.716932 -0.723873  0.312845 -0.311436
# ...        ...       ...       ...       ...       ...       ...       ...
# 4205 -0.470872 -0.112835  0.156089 -0.621732 -0.285414  0.218355 -0.101780
# 4206  0.351739  1.094329 -1.135169  0.756937  0.460980  0.334997 -0.367806
# 4207 -0.628678  0.483028 -0.576387 -0.369208 -0.901375  0.408443 -0.092279
# 4208  0.311377 -0.004242 -0.323030  0.678798 -0.440492  0.213900  0.141697
# 4209 -0.001418 -0.304011 -0.421678 -0.134069  0.284035  0.502283 -0.287106
#
# [4210 rows x 44 columns]

# %%
y = dataSet["spam"]
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: spam, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (3368, 44)

# %%
x_test.shape
# Out:
# (842, 44)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=4,criterion="gini")
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# Accuracy of testing dataset

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.9465558194774347

# %% [markdown]
# Accuracy of Training dataset

# %%
predTrain = model.predict(x_train)
accuracy_score(y_train,predTrain)
# Out:
# 0.9572446555819477

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model,filled=True)
plt.show()
