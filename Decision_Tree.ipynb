# %%
# import necerssary libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataSet = pd.read_csv('spamData.csv')
dataSet
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4205            0.31               0.00           0.62           0.0
# 4206            0.00               0.00           0.00           0.0
# 4207            0.30               0.00           0.30           0.0
# 4208            0.96               0.00           0.00           0.0
# 4209            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0              0.32            0.00              0.00                0.00
# 1              0.14            0.28              0.21                0.07
# 2              1.23            0.19              0.19                0.12
# 3              0.63            0.00              0.31                0.63
# 4              0.63            0.00              0.31                0.63
# ...             ...             ...               ...                 ...
# 4205           0.00            0.31              0.00                0.00
# 4206           0.00            0.00              0.00                0.00
# 4207           0.00            0.00              0.00                0.00
# 4208           0.32            0.00              0.00                0.00
# 4209           0.00            0.00              0.00                0.00
#
#       word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0                0.00            0.00  ...        0.000        0.000
# 1                0.00            0.94  ...        0.000        0.132
# 2                0.64            0.25  ...        0.010        0.143
# 3                0.31            0.63  ...        0.000        0.137
# 4                0.31            0.63  ...        0.000        0.135
# ...               ...             ...  ...          ...          ...
# 4205             0.00            0.00  ...        0.000        0.232
# 4206             0.00            0.00  ...        0.000        0.000
# 4207             0.00            0.00  ...        0.102        0.718
# 4208             0.00            0.00  ...        0.000        0.057
# 4209             0.00            0.00  ...        0.000        0.000
#
#       char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0             0.0        0.778        0.000        0.000
# 1             0.0        0.372        0.180        0.048
# 2             0.0        0.276        0.184        0.010
# 3             0.0        0.137        0.000        0.000
# 4             0.0        0.135        0.000        0.000
# ...           ...          ...          ...          ...
# 4205          0.0        0.000        0.000        0.000
# 4206          0.0        0.353        0.000        0.000
# 4207          0.0        0.000        0.000        0.000
# 4208          0.0        0.000        0.000        0.000
# 4209          0.0        0.125        0.000        0.000
#
#       capital_run_length_average  capital_run_length_longest  \
# 0                          3.756                          61
# 1                          5.114                         101
# 2                          9.821                         485
# 3                          3.537                          40
# 4                          3.537                          40
# ...                          ...                         ...
# 4205                       1.142                           3
# 4206                       1.555                           4
# 4207                       1.404                           6
# 4208                       1.147                           5
# 4209                       1.250                           5
#
#       capital_run_length_total  spam
# 0                          278     1
# 1                         1028     1
# 2                         2259     1
# 3                          191     1
# 4                          191     1
# ...                        ...   ...
# 4205                        88     0
# 4206                        14     0
# 4207                       118     0
# 4208                        78     0
# 4209                        40     0
#
# [4210 rows x 58 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data=scaler.fit_transform(dataSet)

# %%
new_data=pd.DataFrame(data=scaled_data, columns= dataSet.columns)

# %%
new_data.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count    4.210000e+03       4.210000e+03   4.210000e+03   4210.000000
# mean     4.725700e-17       1.350200e-17   2.700400e-17      0.000000
# std      1.000119e+00       1.000119e+00   1.000119e+00      1.000119
# min     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 25%     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 50%     -3.479216e-01      -2.480275e-01  -5.652450e-01     -0.046644
# 75%     -3.479216e-01      -2.480275e-01   2.880349e-01     -0.046644
# max      1.478696e+01       3.119145e+01   9.325045e+00     31.609920
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count   4.210000e+03    4.210000e+03       4210.000000        4.210000e+03
# mean    4.050600e-17   -1.350200e-17          0.000000       -1.350200e-17
# std     1.000119e+00    1.000119e+00          1.000119        1.000119e+00
# min    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 25%    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 50%    -4.730399e-01   -3.502046e-01         -0.295731       -2.632646e-01
# 75%     1.231299e-01   -3.502046e-01         -0.295731       -2.632646e-01
# max     1.406769e+01    2.095434e+01         18.005710        2.681886e+01
#
#        word_freq_order  word_freq_mail  ...  char_freq_;   char_freq_(  \
# count      4210.000000    4.210000e+03  ...  4210.000000  4.210000e+03
# mean          0.000000   -8.776300e-17  ...     0.000000 -6.751000e-18
# std           1.000119    1.000119e+00  ...     1.000119  1.000119e+00
# min          -0.325617   -3.783664e-01  ...    -0.160010 -5.252942e-01
# 25%          -0.325617   -3.783664e-01  ...    -0.160010 -5.252942e-01
# 50%          -0.325617   -3.783664e-01  ...    -0.160010 -2.590883e-01
# 75%          -0.325617   -8.897950e-02  ...    -0.160010  1.821569e-01
# max          18.319574    2.731139e+01  ...    17.206130  3.503689e+01
#
#         char_freq_[   char_freq_!   char_freq_$   char_freq_#  \
# count  4.210000e+03  4.210000e+03  4.210000e+03  4.210000e+03
# mean   1.350200e-17 -2.700400e-17 -2.700400e-17  2.700400e-17
# std    1.000119e+00  1.000119e+00  1.000119e+00  1.000119e+00
# min   -1.643641e-01 -3.334068e-01 -3.173253e-01 -1.050711e-01
# 25%   -1.643641e-01 -3.334068e-01 -3.173253e-01 -1.050711e-01
# 50%   -1.643641e-01 -3.144319e-01 -3.173253e-01 -1.050711e-01
# 75%   -1.643641e-01  5.913558e-02 -9.619715e-02 -1.050711e-01
# max    3.843832e+01  3.818318e+01  2.472857e+01  4.538756e+01
#
#        capital_run_length_average  capital_run_length_longest  \
# count                4.210000e+03                4.210000e+03
# mean                -1.350200e-17               -1.350200e-17
# std                  1.000119e+00                1.000119e+00
# min                 -1.322705e-01               -2.562653e-01
# 25%                 -1.133376e-01               -2.261989e-01
# 50%                 -9.313751e-02               -1.861104e-01
# 75%                 -5.060267e-02               -4.078958e-02
# max                  3.310208e+01                4.979423e+01
#
#        capital_run_length_total         spam
# count              4.210000e+03  4210.000000
# mean              -2.700400e-17     0.000000
# std                1.000119e+00     1.000119
# min               -4.691088e-01    -0.814478
# 25%               -4.060613e-01    -0.814478
# 50%               -3.066403e-01    -0.814478
# 75%               -2.818053e-02     1.227780
# max                2.513787e+01     1.227780
#
# [8 rows x 58 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA()
principalComponents = pca.fit_transform(new_data)

# %%
plt.scatter(principalComponents[:, 0], principalComponents[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %%
pca = PCA(n_components=44)
new_data = pca.fit_transform(new_data)

# This will be the new data fed to the algorithm.
new_data = pd.DataFrame(data = new_data
             , columns = ['PC1', 'PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20',
                         'PC21', 'PC22','PC23','PC24','PC25','PC26','PC27','PC28','PC29','PC30','PC31','PC32','PC33','PC34','PC35','PC36','PC37','PC38','PC39','PC40',
                         'PC41','PC42','PC43','PC44'])

# %%
new_data.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -0.959823  0.409807 -0.704631  0.050895 -0.290680 -0.307122 -0.093054
# 1 -1.577182  2.120003  0.145525 -0.496399  0.054552 -1.145476 -0.554159
# 2 -2.027952  4.587556  3.385877 -1.134822  1.772881 -1.325301 -3.197687
# 3 -1.069772  0.743200 -0.596388 -0.017244 -0.169487  0.719956  0.345824
# 4 -1.070586  0.742542 -0.598528 -0.017511 -0.169507  0.720514  0.344097
#
#         PC8       PC9      PC10  ...      PC35      PC36      PC37      PC38  \
# 0  0.361764  1.750161  0.043567  ...  0.347521  0.482229  0.027210  0.134739
# 1  0.249047 -0.301003  0.686665  ... -0.263540 -0.173845 -0.372700 -0.147253
# 2 -1.352007  1.000607 -2.300503  ...  2.073959 -0.477921 -0.504970 -0.235333
# 3 -0.442139 -0.370907 -0.241561  ...  0.327135  0.225906  0.068567  0.299284
# 4 -0.443469 -0.371230 -0.240767  ...  0.326502  0.227104  0.069729  0.299743
#
#        PC39      PC40      PC41      PC42      PC43      PC44
# 0  0.192877  0.200337  0.284751  0.236153 -0.339062  0.382795
# 1  0.012959  0.236199  0.345216  0.566690  0.069066  0.355063
# 2 -0.443431  0.974879  0.766751  0.403190  0.155549 -0.947094
# 3 -0.405302  0.545987  0.720293 -0.706206  0.318126 -0.289082
# 4 -0.405263  0.546365  0.719577 -0.704742  0.318038 -0.288268
#
# [5 rows x 44 columns]

# %%
print(pca.explained_variance_)
# Out:
# [6.34931299 3.59100245 2.02185167 1.62967807 1.55865658 1.47438413
#  1.41600614 1.3678382  1.29487442 1.25872121 1.24078703 1.16188678
#  1.14582226 1.10618505 1.09853396 1.0650937  1.05387191 1.02942109
#  1.01691551 1.00182143 0.98030358 0.96920233 0.95323634 0.94501255
#  0.93891318 0.91880109 0.90733058 0.89585053 0.87390572 0.86555029
#  0.83277201 0.82201819 0.81020339 0.80444593 0.78845922 0.76093918
#  0.75974631 0.74236492 0.72789481 0.70545864 0.68255121 0.67157797
#  0.63897502 0.63185657]

# %%
print(pca.components_)
# Out:
# [[-0.05217652 -0.0253257  -0.05860725 ... -0.04370125 -0.0588821
#   -0.16243752]
#  [ 0.11983787  0.09668062  0.12556813 ...  0.20153921  0.17812588
#    0.35400338]
#  [-0.01555129 -0.01189857 -0.01805091 ...  0.4790473   0.40097302
#   -0.06402025]
#  ...
#  [-0.14440426  0.17765069  0.00879567 ...  0.05202281  0.47804951
#    0.03960713]
#  [ 0.14139889  0.09091064  0.06963308 ...  0.02779425  0.11447057
#    0.03418088]
#  [ 0.13408993 -0.30188002  0.00920825 ... -0.0275126   0.30635015
#    0.11968933]]

# %% [markdown]
# Scree plot

# %%
plt.plot((np.arange(pca.n_components_)),pca.explained_variance_ratio_,"bo-",linewidth=2)
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')
plt.title('Scree Plot')
plt.show()

# %% [markdown]
# Variance Explanation plot

# %%
plt.bar(range(1,len(pca.explained_variance_ratio_)+1),pca.explained_variance_ratio_,alpha=0.5,align="center")
plt.xlabel('Principal Component')
plt.ylabel('Proportion of Variance Explained')
plt.title('Variance Explanation Plot')
plt.show()

# %% [markdown]
# Cumulative variance plot

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Variance (%)') #for each component
plt.title('Explained Variance')
plt.show()

# %% [markdown]
# Decision Tree

# %%
x = new_data
x
# Out:
#            PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0    -0.959823  0.409807 -0.704631  0.050895 -0.290680 -0.307122 -0.093054
# 1    -1.577182  2.120003  0.145525 -0.496399  0.054552 -1.145476 -0.554159
# 2    -2.027952  4.587556  3.385877 -1.134822  1.772881 -1.325301 -3.197687
# 3    -1.069772  0.743200 -0.596388 -0.017244 -0.169487  0.719956  0.345824
# 4    -1.070586  0.742542 -0.598528 -0.017511 -0.169507  0.720514  0.344097
# ...        ...       ...       ...       ...       ...       ...       ...
# 4205 -0.247325 -1.196337 -0.071688  0.545853  0.392236 -0.820541  0.140341
# 4206 -0.630631 -0.960296 -1.097316 -0.491291 -0.860420 -0.706838  0.887414
# 4207 -0.095734 -0.906405  0.406455  0.144089  0.172341 -1.020226  0.267713
# 4208 -0.399717 -1.063003 -0.433081  0.276414 -0.093437 -0.857474  0.433724
# 4209 -0.558281 -1.056117 -0.876781 -0.480016 -0.550993 -1.433964  0.517835
#
#            PC8       PC9      PC10  ...      PC35      PC36      PC37  \
# 0     0.361764  1.750161  0.043567  ...  0.347521  0.482229  0.027210
# 1     0.249047 -0.301003  0.686665  ... -0.263540 -0.173845 -0.372700
# 2    -1.352007  1.000607 -2.300503  ...  2.073959 -0.477921 -0.504970
# 3    -0.442139 -0.370907 -0.241561  ...  0.327135  0.225906  0.068567
# 4    -0.443469 -0.371230 -0.240767  ...  0.326502  0.227104  0.069729
# ...        ...       ...       ...  ...       ...       ...       ...
# 4205 -0.219174 -0.068269  0.563860  ... -0.139094  0.007292  0.256604
# 4206  0.742194 -0.540947  0.190370  ... -0.032120  0.746571 -0.283894
# 4207  0.316306  0.258942  0.682219  ...  0.670655  0.001040 -0.002113
# 4208  0.093354 -0.354622  0.883140  ...  0.498316  0.431505 -0.572753
# 4209  0.755886 -0.297505  0.037701  ... -0.164389 -0.747522 -0.084387
#
#           PC38      PC39      PC40      PC41      PC42      PC43      PC44
# 0     0.134739  0.192877  0.200337  0.284751  0.236153 -0.339062  0.382795
# 1    -0.147253  0.012959  0.236199  0.345216  0.566690  0.069066  0.355063
# 2    -0.235333 -0.443431  0.974879  0.766751  0.403190  0.155549 -0.947094
# 3     0.299284 -0.405302  0.545987  0.720293 -0.706206  0.318126 -0.289082
# 4     0.299743 -0.405263  0.546365  0.719577 -0.704742  0.318038 -0.288268
# ...        ...       ...       ...       ...       ...       ...       ...
# 4205 -0.472851 -0.113566  0.151033 -0.620319 -0.290336  0.219934 -0.107759
# 4206  0.338820  1.085247 -1.186909  0.768017  0.429490  0.352231 -0.353168
# 4207 -0.633532  0.477687 -0.610641 -0.371585 -0.908956  0.416901 -0.094117
# 4208  0.309185 -0.006048 -0.298505  0.695872 -0.436615  0.213154  0.147801
# 4209 -0.004305 -0.307012 -0.430256 -0.129933  0.271289  0.507764 -0.278886
#
# [4210 rows x 44 columns]

# %%
y = dataSet["spam"]
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: spam, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (3368, 44)

# %%
x_test.shape
# Out:
# (842, 44)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=4,criterion="gini")
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# Accuracy of testing dataset

# %%
pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, pred)
percentage_accuracy = accuracy*100
percentage_accuracy
# Out:
# 93.82422802850357

# %% [markdown]
# Accuracy of Training dataset

# %%
predTrain = model.predict(x_train)
accuracy = accuracy_score(y_train,predTrain)
percentage_accuracy = accuracy*100
percentage_accuracy
# Out:
# 95.04156769596199

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, pred)
cm
# Out:
# array([[482,  37],
#        [ 15, 308]], dtype=int64)

# %%
# based on test values generate the confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Summary of the predictions made by the classifier
mat = confusion_matrix(y_test, pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=True)

plt.title('Confusion matrix')
plt.xlabel('true class')
plt.ylabel('predicted class')
# Out:
# Text(77.92222222222227, 0.5, 'predicted class')

# %%
# Generate summary of the prediction (Classification Report) made by the classifier
from sklearn.metrics import classification_report

print('Classification Report : \n\n')
print(classification_report(y_test,pred))
# Out:
# Classification Report :
#
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       519
#            1       0.89      0.95      0.92       323
#
#     accuracy                           0.94       842
#    macro avg       0.93      0.94      0.94       842
# weighted avg       0.94      0.94      0.94       842

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model,filled=True)
plt.show()
